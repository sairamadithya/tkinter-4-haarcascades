# %%
import cv2
import numpy as np
import tkinter
from PIL import ImageTk,Image 
def cap11():
    colour=c1_col.get()
    cap = cv2.VideoCapture(0)
    fourcc = cv2.VideoWriter_fourcc('X','V','I','D')
    out = cv2.VideoWriter('op1.avi', fourcc, 4.0, (640,480))
    while True:
        success, frame = cap.read() 
        faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
        imgGray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = faceCascade.detectMultiScale(imgGray, 1.1, 4)
        for (x, y, w, h) in faces:
            if colour=='red':
                cv2.rectangle(frame, (x,y),(x+w,y+h),(0,0,255),4)
            elif colour=='green':
                cv2.rectangle(frame, (x,y),(x+w,y+h),(0,255,0),4)
            elif colour=='blue':
                cv2.rectangle(frame, (x,y),(x+w,y+h),(255,0,0),4)
            elif colour=='black':
                cv2.rectangle(frame, (x,y),(x+w,y+h),(0,0,0),4)
            else:
                cv2.rectangle(frame, (x,y),(x+w,y+h),(255,255,255),4)
        if success==True:
            out.write(frame)
            cv2.imshow("Video", frame)
            if cv2.waitKey(1) == ord('q'):
                break
        else:
            break
    cap.release() #Release the resources after recording
    out.release()
    cv2.destroyAllWindows()
def cap12():
    colour=c2_col.get()
    cap = cv2.VideoCapture(0)
    fourcc = cv2.VideoWriter_fourcc('X','V','I','D')
    out = cv2.VideoWriter('op1.avi', fourcc, 4.0, (640,480))
    while True:
        success, frame = cap.read() 
        faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
        imgGray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = faceCascade.detectMultiScale(imgGray, 1.1, 4)
        for (x, y, w, h) in faces:
            if colour=='red':
                cv2.rectangle(frame, (x,y),(x+w,y+h),(0,0,255),-1)
            elif colour=='green':
                cv2.rectangle(frame, (x,y),(x+w,y+h),(0,255,0),-1)
            elif colour=='blue':
                cv2.rectangle(frame, (x,y),(x+w,y+h),(255,0,),-1)
            elif colour=='black':
                cv2.rectangle(frame, (x,y),(x+w,y+h),(0,0,0),-1)
            else:
                cv2.rectangle(frame, (x,y),(x+w,y+h),(255,255,255),-1)
        if success==True:
            out.write(frame)
            cv2.imshow("Video", frame)
            if cv2.waitKey(1) == ord('q'):
                break
        else:
            break
    cap.release() #Release the resources after recording
    out.release()
    cv2.destroyAllWindows()
def cap13():
    colour=c3_col.get()
    cap = cv2.VideoCapture(0)
    fourcc = cv2.VideoWriter_fourcc('X','V','I','D')
    out = cv2.VideoWriter('op1.avi', fourcc, 4.0, (640,480))
    while True:
        success, frame = cap.read() 
        eyecascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')
        imgGray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = eyecascade.detectMultiScale(imgGray, 1.1, 4)
        for (x, y, w, h) in faces:
            if colour=='red':
                cv2.rectangle(frame, (x,y),(x+w,y+h),(0,0,255),4)
            elif colour=='green':
                cv2.rectangle(frame, (x,y),(x+w,y+h),(0,255,0),4)
            elif colour=='blue':
                cv2.rectangle(frame, (x,y),(x+w,y+h),(255,0,),4)
            elif colour=='black':
                cv2.rectangle(frame, (x,y),(x+w,y+h),(0,0,0),4)
            else:
                cv2.rectangle(frame, (x,y),(x+w,y+h),(255,255,255),4)
        if success==True:
            out.write(frame)
            cv2.imshow("Video", frame)
            if cv2.waitKey(1) == ord('q'):
                break
        else:
            break
    cap.release() #Release the resources after recording
    out.release()
    cv2.destroyAllWindows()  
def cap14():
    colour=c4_col.get()
    cap = cv2.VideoCapture(0)
    fourcc = cv2.VideoWriter_fourcc('X','V','I','D')
    out = cv2.VideoWriter('op1.avi', fourcc, 4.0, (640,480))
    while True:
        success, frame = cap.read() 
        eyecascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')
        imgGray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = eyecascade.detectMultiScale(imgGray, 1.1, 4)
        for (x, y, w, h) in faces:
            if (colour=='red'):
                cv2.rectangle(frame, (x,y),(x+w,y+h),(0,0,255),-1)
            elif colour=='green':
                cv2.rectangle(frame, (x,y),(x+w,y+h),(0,255,0),-1)
            elif colour=='blue':
                cv2.rectangle(frame, (x,y),(x+w,y+h),(255,0,),-1)
            elif colour=='black':
                cv2.rectangle(frame, (x,y),(x+w,y+h),(0,0,0),-1)
            else:
                cv2.rectangle(frame, (x,y),(x+w,y+h),(255,255,255),-1)
        if success==True:
            out.write(frame)
            cv2.imshow("Video", frame)
            if cv2.waitKey(1) == ord('q'):
                break
        else:
            break
    cap.release() #Release the resources after recording
    out.release()
    cv2.destroyAllWindows()
def cap15():
    colour=c5_col.get()
    cap = cv2.VideoCapture(0)
    fourcc = cv2.VideoWriter_fourcc('X','V','I','D')
    out = cv2.VideoWriter('op1.avi', fourcc, 4.0, (640,480))
    while True:
        success, frame = cap.read() 
        fbcascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_lefteye_2splits.xml')
        imgGray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = fbcascade.detectMultiScale(imgGray, 1.1, 4)
        for (x, y, w, h) in faces:
            if colour=='red':
                cv2.rectangle(frame, (x,y),(x+w,y+h),(0,0,255),4)
            elif colour=='green':
                cv2.rectangle(frame, (x,y),(x+w,y+h),(0,255,0),4)
            elif colour=='blue':
                cv2.rectangle(frame, (x,y),(x+w,y+h),(255,0,),4)
            elif colour=='black':
                cv2.rectangle(frame, (x,y),(x+w,y+h),(0,0,0),4)
            else:
                cv2.rectangle(frame, (x,y),(x+w,y+h),(255,255,255),4)
        if success==True:
            out.write(frame)
            cv2.imshow("Video", frame)
            if cv2.waitKey(1) == ord('q'):
                break
        else:
            break
    cap.release() #Release the resources after recording
    out.release()
    cv2.destroyAllWindows() 
def cap16():
    colour=c6_col.get()
    cap = cv2.VideoCapture(0)
    fourcc = cv2.VideoWriter_fourcc('X','V','I','D')
    out = cv2.VideoWriter('op1.avi', fourcc, 4.0, (640,480))
    while True:
        success, frame = cap.read() 
        fbcascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_righteye_2splits.xml')
        imgGray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = fbcascade.detectMultiScale(imgGray, 1.1, 4)
        for (x, y, w, h) in faces:
            if colour=='red':
                cv2.rectangle(frame, (x,y),(x+w,y+h),(0,0,255),4)
            elif colour=='green':
                cv2.rectangle(frame, (x,y),(x+w,y+h),(0,255,0),4)
            elif colour=='blue':
                cv2.rectangle(frame, (x,y),(x+w,y+h),(255,0,),4)
            elif colour=='black':
                cv2.rectangle(frame, (x,y),(x+w,y+h),(0,0,0),4)
            else:
                cv2.rectangle(frame, (x,y),(x+w,y+h),(255,255,255),4)
        if success==True:
            out.write(frame)
            cv2.imshow("Video", frame)
            if cv2.waitKey(1) == ord('q'):
                break
        else:
            break
    cap.release() #Release the resources after recording
    out.release()
    cv2.destroyAllWindows()     
app=tkinter.Tk()
app.geometry("2000x2000")
app.title("VIDEO PROCESSING GUI")
app.config(bg='orange')
c1_col=tkinter.StringVar()
c2_col=tkinter.StringVar()
c3_col=tkinter.StringVar()
c4_col=tkinter.StringVar()
c5_col=tkinter.StringVar()
c6_col=tkinter.StringVar()

tkinter.Label(app,text='WELCOME TO THE PROJECT!!',font=("Arial",22,'bold'),fg='blue',bg='orange').place(x=450,y=0)
tkinter.Label(app,text='HAAR CASCADES GUI',font=("Arial",22,'bold'),fg='blue',bg='orange').place(x=495,y=35)  
tkinter.Label(app,text='CHOOSE THIS TO DETECT FACE IN VIDEO',font=("Arial",12,'bold'),fg='yellow',bg='black').place(x=10,y=70)
tkinter.Label(app,text='ENTER THE COLOUR (red,green,blue,black,white)',font=("Arial",12,'bold'),fg='black',bg='pink').place(x=10,y=90)
tkinter.Entry(app,textvariable=c1_col).place(x=500,y=90)
tkinter.Button(app,text='FACE-DETECTOR',bg='yellow',command=cap11).place(x=10,y=120)
tkinter.Label(app,text='CHOOSE THIS TO BLOCK FACE IN VIDEO',font=("Arial",12,'bold'),fg='yellow',bg='black').place(x=10,y=150)
tkinter.Label(app,text='ENTER THE COLOUR (red,green,blue,black,white)',font=("Arial",12,'bold'),fg='black',bg='pink').place(x=10,y=170)
tkinter.Entry(app,textvariable=c2_col).place(x=500,y=170)
tkinter.Button(app,text='FACE-BLOCKER',bg='yellow',command=cap12).place(x=10,y=200)
tkinter.Label(app,text='CHOOSE THIS TO DETECT EYE IN VIDEO',font=("Arial",12,'bold'),fg='yellow',bg='black').place(x=10,y=230)
tkinter.Label(app,text='ENTER THE COLOUR (red,green,blue,black,white)',font=("Arial",12,'bold'),fg='black',bg='pink').place(x=10,y=260)
tkinter.Entry(app,textvariable=c3_col).place(x=500,y=260)
tkinter.Button(app,text='EYE-DETECTOR',bg='yellow',command=cap13).place(x=10,y=290)
tkinter.Label(app,text='CHOOSE THIS TO BLOCK EYE IN VIDEO',font=("Arial",12,'bold'),fg='yellow',bg='black').place(x=10,y=320)
tkinter.Label(app,text='ENTER THE COLOUR (red,green,blue,black,white)',font=("Arial",12,'bold'),fg='black',bg='pink').place(x=10,y=350)
tkinter.Entry(app,textvariable=c4_col).place(x=500,y=350)
tkinter.Button(app,text='EYE-BLOCKER',bg='yellow',command=cap14).place(x=10,y=380)
tkinter.Label(app,text='CHOOSE THIS TO DETECT LEFT EYE',font=("Arial",12,'bold'),fg='yellow',bg='black').place(x=10,y=410)
tkinter.Label(app,text='ENTER THE COLOUR (red,green,blue,black,white)',font=("Arial",12,'bold'),fg='black',bg='pink').place(x=10,y=440)
tkinter.Entry(app,textvariable=c5_col).place(x=500,y=440)
tkinter.Button(app,text='LEFT EYE-DETECTOR',bg='yellow',command=cap15).place(x=10,y=470)
tkinter.Label(app,text='CHOOSE THIS TO DETECT RIGHT EYE',font=("Arial",12,'bold'),fg='yellow',bg='black').place(x=10,y=500)
tkinter.Label(app,text='ENTER THE COLOUR (red,green,blue,black,white)',font=("Arial",12,'bold'),fg='black',bg='pink').place(x=10,y=520)
tkinter.Entry(app,textvariable=c6_col).place(x=500,y=540)
tkinter.Button(app,text='RIGHT EYE-DETECTOR',bg='yellow',command=cap16).place(x=10,y=560)
tkinter.Label(app,text='**PRESS q IN KEYBOARD TO STOP THE WEBCAM**',font=("Arial",16,'bold'),fg='cyan',bg='black').place(x=10,y=600)
tkinter.Label(app,text='HAAR CASCADE is an Object Detection Algorithm used to identify',font=("Arial",12,'bold'),fg='pink',bg='black').place(x=700,y=300)
tkinter.Label(app,text='faces or eyes or bodies in an image or a real time video',font=("Arial",12,'bold'),fg='pink',bg='black').place(x=700,y=330)    
tkinter.Label(app,text='The algorithm uses edge or line detection features proposed by',font=("Arial",12,'bold'),fg='pink',bg='black').place(x=700,y=360)
tkinter.Label(app,text='Viola and Jones in their research paper',font=("Arial",12,'bold'),fg='pink',bg='black').place(x=700,y=390)
tkinter.Label(app,text='“Rapid Object Detection using a Boosted ',font=("Arial",12,'bold'),fg='pink',bg='black').place(x=700,y=420)
tkinter.Label(app,text=' Cascade of Simple Features” published in 2001.',font=("Arial",12,'bold'),fg='pink',bg='black').place(x=700,y=450)
img=Image.open("C:\\Users\\sairam\\Desktop\load.png")
test = ImageTk.PhotoImage(img)
label1 = tkinter.Label(image=test)
label1.image = test
label1.place(x=800,y=80)
  
tkinter.Label(app,text='THANK YOU FOR USING THIS APPLICATION',font=('Arial',36,'bold'),fg='orange',bg='red').place(x=200,y=640)
    
    
              
app.mainloop()
